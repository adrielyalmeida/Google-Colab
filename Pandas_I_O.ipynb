# %% [markdown]
# <a href="https://colab.research.google.com/github/adrielyalmeida/Google-Colab/blob/main/Pandas_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# acrescento a parte final ?raw=True para poder trazer o arquivo raw

# %%
url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %% [markdown]
# Para saber se existe mais de uma planilha nesse arquivo

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %% [markdown]
# Para acessar a outra planilha do arquivo, pois por padrão mostra a primeira. Se quiser ver outyra, tenho que especificar

# %%
percapita = pd.read_excel(url, sheet_name='emissoes_percapita')

# %%
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url, sheet_name='fontes')

# %%
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %% [markdown]
# Para selecionar colunas específicas

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D')

# %%
intervalo
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total
# 0      Afeganistão                AFG  1750  0.000000e+00
# 1      Afeganistão                AFG  1751  0.000000e+00
# 2      Afeganistão                AFG  1752  0.000000e+00
# 3      Afeganistão                AFG  1753  0.000000e+00
# 4      Afeganistão                AFG  1754  0.000000e+00
# ...            ...                ...   ...           ...
# 63099       Global                WLD  2017  3.609674e+10
# 63100       Global                WLD  2018  3.682651e+10
# 63101       Global                WLD  2019  3.708256e+10
# 63102       Global                WLD  2020  3.526409e+10
# 63103       Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# Para mostrar só as 10 primeiras linhas

# %%
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D', nrows=10)

# %%
intervalo_2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %% [markdown]
# Para salvar um dataframe no formato excel

# %%
percapita.to_excel('co2_percapita.xlsx', index=False)

# %% [markdown]
# Ler o arquivo que foi salvo

# %%
pd.read_excel('/content/co2_percapita.xlsx')
# Out:
#               País ISO 3166-1 alpha-3   Ano      Total     Carvão       Óleo  \
# 0      Afeganistão                AFG  1750        NaN        NaN        NaN
# 1      Afeganistão                AFG  1751        NaN        NaN        NaN
# 2      Afeganistão                AFG  1752        NaN        NaN        NaN
# 3      Afeganistão                AFG  1753        NaN        NaN        NaN
# 4      Afeganistão                AFG  1754        NaN        NaN        NaN
# ...            ...                ...   ...        ...        ...        ...
# 63099       Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100       Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101       Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102       Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103       Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gás   Cimento   Queima    Outro
# 0            NaN       NaN      NaN      NaN
# 1            NaN       NaN      NaN      NaN
# 2            NaN       NaN      NaN      NaN
# 3            NaN       NaN      NaN      NaN
# 4            NaN       NaN      NaN      NaN
# ...          ...       ...      ...      ...
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0
#
# [63104 rows x 10 columns]

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1OhdjndjI_iIoj78xsNyHnakwFGh1pNuULV6zP4BaKkk/edit?usp=sharing

# %%
sheet_id = '1OhdjndjI_iIoj78xsNyHnakwFGh1pNuULV6zP4BaKkk'

# %%
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_co2_sheets = pd.read_csv(url)

# %%
dados_co2_sheets.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano Total Carvão Oléo  Gás Cimento Queima  \
# 0  Afeganistão                AFG  1750     0    NaN  NaN  NaN     NaN    NaN
# 1  Afeganistão                AFG  1751     0    NaN  NaN  NaN     NaN    NaN
# 2  Afeganistão                AFG  1752     0    NaN  NaN  NaN     NaN    NaN
# 3  Afeganistão                AFG  1753     0    NaN  NaN  NaN     NaN    NaN
# 4  Afeganistão                AFG  1754     0    NaN  NaN  NaN     NaN    NaN
#
#   Outro Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
sheet_id = '1OhdjndjI_iIoj78xsNyHnakwFGh1pNuULV6zP4BaKkk'
sheet_name = 'emissoes_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)

# %%
percapita_sheets.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano Total Carvão Óleo  Gás Cimento Queima  \
# 0  Afeganistão                AFG  1750   NaN    NaN  NaN  NaN     NaN    NaN
# 1  Afeganistão                AFG  1751   NaN    NaN  NaN  NaN     NaN    NaN
# 2  Afeganistão                AFG  1752   NaN    NaN  NaN  NaN     NaN    NaN
# 3  Afeganistão                AFG  1753   NaN    NaN  NaN  NaN     NaN    NaN
# 4  Afeganistão                AFG  1754   NaN    NaN  NaN  NaN     NaN    NaN
#
#    Outro
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
sheet_id = '1OhdjndjI_iIoj78xsNyHnakwFGh1pNuULV6zP4BaKkk'
sheet_name = 'fontes'
url_fontes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fontes_sheets = pd.read_csv(url_fontes)

# %%
fontes_sheets.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
dados_videos = pd.read_json('/content/videos.json')

# %%
dados_videos
# Out:
#                                                videos
# 0   {'id': 1, 'titulo': 'Conhecendo a linguagem Go...
# 1   {'id': 2, 'titulo': 'Desmistificando mobile - ...
# 2   {'id': 3, 'titulo': 'Orientação a objetos com ...
# 3   {'id': 4, 'titulo': 'Linguagens e ferramentas ...
# 4   {'id': 5, 'titulo': 'Reencontrando a paixão po...
# 5   {'id': 6, 'titulo': 'Híbridos: Flutter e React...
# 6   {'id': 7, 'titulo': 'Data Science na prática- ...
# 7   {'id': 8, 'titulo': 'baNaNa | Memes do JavaScr...
# 8   {'titulo': '[Casa do Código] Live de lançament...
# 9   {'titulo': 'Guia de carreira Front-end | #Hips...
# 10  {'titulo': 'Educação coorporativa', 'descricao...
# 11  {'titulo': 'Como deixar o Layout Responsivo no...
# 12  {'titulo': 'Será que a inteligência artificial...

# %%
df_normalizado = pd.json_normalize(dados_videos['videos'])

# %%
df_normalizado
# Out:
#     id                                             titulo  \
# 0    1         Conhecendo a linguagem Go | Hipsters.Talks
# 1    2   Desmistificando mobile - Linguagens e Frameworks
# 2    3  Orientação a objetos com Roberta Arcoverde | #...
# 3    4  Linguagens e ferramentas usadas em Ciência de ...
# 4    5  Reencontrando a paixão por programar: Beatriz ...
# 5    6  Híbridos: Flutter e React Native | Desmistific...
# 6    7  Data Science na prática- com Jéssika Ribeiro d...
# 7    8                    baNaNa | Memes do JavaScript #2
# 8    9  [Casa do Código] Live de lançamento: Navegando...
# 9   10    Guia de carreira Front-end | #HipstersPontoTube
# 10  11                              Educação coorporativa
# 11  12  Como deixar o Layout Responsivo no seu site | ...
# 12  13  Será que a inteligência artificial será tão po...
#
#                 descricao                                        url  \
# 0     3 mil visualizações  https://www.youtube.com/embed/y8FeZMv37WU
# 1   1,5 mil visualizações  https://www.youtube.com/embed/fmu1LQvZhms
# 2    30 mil visualizações  https://www.youtube.com/embed/jpuJ1qrluoU
# 3   2,5 mil visualizações  https://www.youtube.com/embed/h83e1aAM5xQ
# 4   1,2 mil visualizações  https://www.youtube.com/embed/CnB3eLTrkn4
# 5   1,6 mil visualizações  https://www.youtube.com/embed/vf9P_PycgRw
# 6   3,2 mil visualizações  https://www.youtube.com/embed/Nts3P35mHzE
# 7   1,2 mil visualizações  https://www.youtube.com/embed/HBVCsBtsmzA
# 8     1 mil visualizações  https://www.youtube.com/embed/z43rcfjXOxU
# 9    18 mil visualizações  https://www.youtube.com/embed/fpth65ts3cw
# 10    4 mil visualizações  https://www.youtube.com/embed/IGFSiBJIXFQ
# 11    7 mil visualizações  https://www.youtube.com/embed/kyFiT4ofMwk
# 12   12 mil visualizações  https://www.youtube.com/embed/Kk3vBRqKA2o
#
#                                                imagem                categoria
# 0   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 1   https://github.com/MonicaHillman/aluraplay-req...                   Mobile
# 2   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 3   https://github.com/MonicaHillman/aluraplay-req...             Data Science
# 4   https://github.com/MonicaHillman/aluraplay-req...                 Podcasts
# 5   https://github.com/MonicaHillman/aluraplay-req...                   Mobile
# 6   https://github.com/MonicaHillman/aluraplay-req...             Data Science
# 7   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 8   https://github.com/MonicaHillman/aluraplay-req...                  Ao Vivo
# 9   https://github.com/MonicaHillman/aluraplay-req...                  Debates
# 10  https://github.com/MonicaHillman/aluraplay-req...                 Inovação
# 11  https://github.com/MonicaHillman/aluraplay-req...                Front-end
# 12  https://github.com/MonicaHillman/aluraplay-req...  Inteligência Artificial

# %%
df_normalizado.to_json('Histórico_videos_normalizado.json')

# %%
pd.read_json('/content/Histórico_videos_normalizado.json')
# Out:
#     id                                             titulo  \
# 0    1         Conhecendo a linguagem Go | Hipsters.Talks
# 1    2   Desmistificando mobile - Linguagens e Frameworks
# 2    3  Orientação a objetos com Roberta Arcoverde | #...
# 3    4  Linguagens e ferramentas usadas em Ciência de ...
# 4    5  Reencontrando a paixão por programar: Beatriz ...
# 5    6  Híbridos: Flutter e React Native | Desmistific...
# 6    7  Data Science na prática- com Jéssika Ribeiro d...
# 7    8                    baNaNa | Memes do JavaScript #2
# 8    9  [Casa do Código] Live de lançamento: Navegando...
# 9   10    Guia de carreira Front-end | #HipstersPontoTube
# 10  11                              Educação coorporativa
# 11  12  Como deixar o Layout Responsivo no seu site | ...
# 12  13  Será que a inteligência artificial será tão po...
#
#                 descricao                                        url  \
# 0     3 mil visualizações  https://www.youtube.com/embed/y8FeZMv37WU
# 1   1,5 mil visualizações  https://www.youtube.com/embed/fmu1LQvZhms
# 2    30 mil visualizações  https://www.youtube.com/embed/jpuJ1qrluoU
# 3   2,5 mil visualizações  https://www.youtube.com/embed/h83e1aAM5xQ
# 4   1,2 mil visualizações  https://www.youtube.com/embed/CnB3eLTrkn4
# 5   1,6 mil visualizações  https://www.youtube.com/embed/vf9P_PycgRw
# 6   3,2 mil visualizações  https://www.youtube.com/embed/Nts3P35mHzE
# 7   1,2 mil visualizações  https://www.youtube.com/embed/HBVCsBtsmzA
# 8     1 mil visualizações  https://www.youtube.com/embed/z43rcfjXOxU
# 9    18 mil visualizações  https://www.youtube.com/embed/fpth65ts3cw
# 10    4 mil visualizações  https://www.youtube.com/embed/IGFSiBJIXFQ
# 11    7 mil visualizações  https://www.youtube.com/embed/kyFiT4ofMwk
# 12   12 mil visualizações  https://www.youtube.com/embed/Kk3vBRqKA2o
#
#                                                imagem                categoria
# 0   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 1   https://github.com/MonicaHillman/aluraplay-req...                   Mobile
# 2   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 3   https://github.com/MonicaHillman/aluraplay-req...             Data Science
# 4   https://github.com/MonicaHillman/aluraplay-req...                 Podcasts
# 5   https://github.com/MonicaHillman/aluraplay-req...                   Mobile
# 6   https://github.com/MonicaHillman/aluraplay-req...             Data Science
# 7   https://github.com/MonicaHillman/aluraplay-req...              Programação
# 8   https://github.com/MonicaHillman/aluraplay-req...                  Ao Vivo
# 9   https://github.com/MonicaHillman/aluraplay-req...                  Debates
# 10  https://github.com/MonicaHillman/aluraplay-req...                 Inovação
# 11  https://github.com/MonicaHillman/aluraplay-req...                Front-end
# 12  https://github.com/MonicaHillman/aluraplay-req...  Inteligência Artificial

# %%
dados_html = pd.read_html('/content/Filmes_wikipedia.html')

# %%
dados_html
# Out:
# [                                                    0  \
#  0                                                1998
#  1                                                1999
#  2                                                2000
#  3                                                2001
#  4                                                2002
#  5                                                2003
#  6                                                2004
#  7                                                2005
#  8                                                2005
#  9                                                2006
#  10                                               2006
#  11                                               2007
#  12                                               2008
#  13  .mw-parser-output .hlist dl,.mw-parser-output ...
#
#                                                      1
#  0                                          100 Movies
#  1                                           100 Stars
#  2                                          100 Laughs
#  3                                         100 Thrills
#  4                                        100 Passions
#  5                               100 Heroes & Villains
#  6                                           100 Songs
#  7                                    100 Movie Quotes
#  8                                           25 Scores
#  9                                          100 Cheers
#  10                                        25 Musicals
#  11                               100 Movies (Updated)
#  12                                    AFI's 10 Top 10
#  13  .mw-parser-output .hlist dl,.mw-parser-output ...  ,
#                        Film  Release year              Director  \
#  0             Citizen Kane          1941          Orson Welles
#  1               Casablanca          1942        Michael Curtiz
#  2            The Godfather          1972  Francis Ford Coppola
#  3       Gone with the Wind          1939        Victor Fleming
#  4       Lawrence of Arabia          1962            David Lean
#  ..                     ...           ...                   ...
#  118        Sophie's Choice          1982        Alan J. Pakula
#  119  The Last Picture Show          1971     Peter Bogdanovich
#  120     Do the Right Thing          1989             Spike Lee
#  121           Blade Runner          1982          Ridley Scott
#  122              Toy Story          1995         John Lasseter
#
#                                Production companies 1998 Rank 2007 Rank
#  0                               RKO Radio Pictures         1         1
#  1                            Warner Bros. Pictures         2         3
#  2           Paramount Pictures, Alfran Productions         3         2
#  3                  Selznick International Pictures         4         6
#  4                                 Horizon Pictures         5         7
#  ..                                             ...       ...       ...
#  118                              ITC Entertainment         -        91
#  119                                BBS Productions         -        95
#  120                  40 Acres and a Mule Filmworks         -        96
#  121                The Ladd Company, Shaw Brothers         -        97
#  122  Walt Disney Pictures, Pixar Animation Studios         -        99
#
#  [123 rows x 6 columns]]

# %%
type(dados_html)
# Out:
# list

# %%
len(dados_html)
# Out:
# 2

# %%
top_filmes = dados_html[1]

# %%
top_filmes
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# 1                            Warner Bros. Pictures         2         3
# 2           Paramount Pictures, Alfran Productions         3         2
# 3                  Selznick International Pictures         4         6
# 4                                 Horizon Pictures         5         7
# ..                                             ...       ...       ...
# 118                              ITC Entertainment         -        91
# 119                                BBS Productions         -        95
# 120                  40 Acres and a Mule Filmworks         -        96
# 121                The Ladd Company, Shaw Brothers         -        97
# 122  Walt Disney Pictures, Pixar Animation Studios         -        99
#
# [123 rows x 6 columns]

# %%
top_filmes.to_html('top_filmes.html')

# %%
top_filmes.to_csv('top_filmes_1998.csv', index=False)

# %%
pd.read_csv('/content/top_filmes_1998.csv')
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# 1                            Warner Bros. Pictures         2         3
# 2           Paramount Pictures, Alfran Productions         3         2
# 3                  Selznick International Pictures         4         6
# 4                                 Horizon Pictures         5         7
# ..                                             ...       ...       ...
# 118                              ITC Entertainment         -        91
# 119                                BBS Productions         -        95
# 120                  40 Acres and a Mule Filmworks         -        96
# 121                The Ladd Company, Shaw Brothers         -        97
# 122  Walt Disney Pictures, Pixar Animation Studios         -        99
#
# [123 rows x 6 columns]

# %%
dados_imdb = pd.read_xml('/content/imdb_top_1000.xml')

# %%
dados_imdb.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444

# %%
dados_imdb.to_xml('filmes_imdb.xml')
